# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([1,2,3,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates = pd.DataFrame(np.random.randn(6,4), index=dates , columns=list("ABCD"))
# index=dates mean ka pehla column
dates
# Out:
#                    A         B         C         D
# 2013-01-01  1.009274 -0.282353  0.154703  0.077826
# 2013-01-02  0.876729 -0.088530 -0.875511  0.127112
# 2013-01-03  0.068659  0.881348  0.430697  0.806012
# 2013-01-04 -1.273658 -0.103480 -0.080939  0.813743
# 2013-01-05  1.542790 -1.146054 -0.763296  0.790673
# 2013-01-06 -0.722967  0.630750  0.139011  0.256887

# %%
# Dictionary= jis hum key deta ha and us key ki value deta hain
dict = {'Aammar':6.0,'Farman':5.5}

# %%
# 
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[ns]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[ns](1), float32(1), float64(1), int32(1), object(1)
# memory usage: 288.0+ bytes

# %%
df2.abs
# Out:
# <bound method NDFrame.abs of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.add
# Out:
# <bound method flex_arith_method_FRAME.<locals>.f of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.add_prefix
# Out:
# <bound method NDFrame.add_prefix of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df2.add_suffix("_column ma kuxh aga likhna")
# Prefix means column ka kuxh peecha likhna
# Out:
#    A_column ma kuxh aga likhna B_column ma kuxh aga likhna  \
# 0                          1.0                  2013-01-02
# 1                          1.0                  2013-01-02
# 2                          1.0                  2013-01-02
# 3                          1.0                  2013-01-02
#
#    C_column ma kuxh aga likhna  D_column ma kuxh aga likhna  \
# 0                          1.0                            3
# 1                          1.0                            3
# 2                          1.0                            3
# 3                          1.0                            3
#
#   E_column ma kuxh aga likhna F_column ma kuxh aga likhna
# 0                        test                         foo
# 1                       train                         foo
# 2                        test                         foo
# 3                       train                         foo

# %%
data = {
  "age": [50, 40, 30, 40, 20, 10, 30],
  "qualified": [True, False, False, False, False, True, True]
}
df = pd.DataFrame(data)

newdf = df.add_suffix("_after")
newdf
# Out:
#    age_after  qualified_after
# 0         50             True
# 1         40            False
# 2         30            False
# 3         40            False
# 4         20            False
# 5         10             True
# 6         30             True

# %%
df2.align
# Out:
# <bound method DataFrame.align of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
np.pi
# Out:
# 3.141592653589793

# %%
df.head()
# Out:
#    age  qualified
# 0   50       True
# 1   40      False
# 2   30      False
# 3   40      False
# 4   20      False

# %%
df.tail()
# Out:
#    age  qualified
# 2   30      False
# 3   40      False
# 4   20      False
# 5   10       True
# 6   30       True

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
df
# Out:
#    age  qualified
# 0   50       True
# 1   40      False
# 2   30      False
# 3   40      False
# 4   20      False
# 5   10       True
# 6   30       True

# %%
dates
# Out:
#                    A         B         C         D
# 2013-01-01  1.009274 -0.282353  0.154703  0.077826
# 2013-01-02  0.876729 -0.088530 -0.875511  0.127112
# 2013-01-03  0.068659  0.881348  0.430697  0.806012
# 2013-01-04 -1.273658 -0.103480 -0.080939  0.813743
# 2013-01-05  1.542790 -1.146054 -0.763296  0.790673
# 2013-01-06 -0.722967  0.630750  0.139011  0.256887

# %%
df = dates

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  1.009274 -0.282353  0.154703  0.077826
# 2013-01-02  0.876729 -0.088530 -0.875511  0.127112
# 2013-01-03  0.068659  0.881348  0.430697  0.806012
# 2013-01-04 -1.273658 -0.103480 -0.080939  0.813743
# 2013-01-05  1.542790 -1.146054 -0.763296  0.790673
# 2013-01-06 -0.722967  0.630750  0.139011  0.256887

# %%
# Convert df into numpy
df.to_numpy()
# Ab is ka answer 2 dimesniional ho ga
# Array sirf list of values hoti ha
# Out:
# array([[ 1.00927443, -0.28235329,  0.15470276,  0.07782567],
#        [ 0.87672871, -0.08853032, -0.87551119,  0.12711166],
#        [ 0.06865922,  0.88134845,  0.43069723,  0.80601153],
#        [-1.27365846, -0.10348042, -0.08093929,  0.81374342],
#        [ 1.54278977, -1.14605411, -0.76329629,  0.79067267],
#        [-0.7229671 ,  0.63075032,  0.13901121,  0.25688732]])

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.250138 -0.018053 -0.165889  0.478709
# std    1.090108  0.718940  0.532792  0.360619
# min   -1.273658 -1.146054 -0.875511  0.077826
# 25%   -0.525061 -0.237635 -0.592707  0.159556
# 50%    0.472694 -0.096005  0.029036  0.523780
# 75%    0.976138  0.450930  0.150780  0.802177
# max    1.542790  0.881348  0.430697  0.813743

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    1.009274    0.876729    0.068659   -1.273658    1.542790   -0.722967
# B   -0.282353   -0.088530    0.881348   -0.103480   -1.146054    0.630750
# C    0.154703   -0.875511    0.430697   -0.080939   -0.763296    0.139011
# D    0.077826    0.127112    0.806012    0.813743    0.790673    0.256887

# %% [markdown]
# * Sort By Index

# %%
df.sort_index(axis=0, ascending=False)
# if Axis=0 then rowsa change ho ga 
# if Axis=1 then column change ho ga
# Out:
#                    A         B         C         D
# 2013-01-06 -0.722967  0.630750  0.139011  0.256887
# 2013-01-05  1.542790 -1.146054 -0.763296  0.790673
# 2013-01-04 -1.273658 -0.103480 -0.080939  0.813743
# 2013-01-03  0.068659  0.881348  0.430697  0.806012
# 2013-01-02  0.876729 -0.088530 -0.875511  0.127112
# 2013-01-01  1.009274 -0.282353  0.154703  0.077826

# %% [markdown]
# * Sort By Values

# %%
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2013-01-04 -1.273658 -0.103480 -0.080939  0.813743
# 2013-01-06 -0.722967  0.630750  0.139011  0.256887
# 2013-01-03  0.068659  0.881348  0.430697  0.806012
# 2013-01-02  0.876729 -0.088530 -0.875511  0.127112
# 2013-01-01  1.009274 -0.282353  0.154703  0.077826
# 2013-01-05  1.542790 -1.146054 -0.763296  0.790673

# %%
df.sort_values(by=[["A","B"]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df.sort_values(by=[["A","B"]])
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6912, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908 elif len(by):
#    6909     # len(by) == 1
#    6911     by = by[0]
# ...

# %%
df["A"]

# %%
df[["A","B"]]

# %%
df

# %%
# What are indexing
# Rows ka pehla ko kehta hain index
# Agar un ka columns ka name liya jaye then hum 0,1,2,3,4 ginta hain
# Like df ka kitna columns hain = 4 
# df ki range ktni ha = 0-3

# %%
df[0:3]

# %%
df.iloc[0:3,0:2]
# iloc function tab use hota ha jab index ko lock krna ka liya

# %%
df.loc[:,["A","B"]] # Loc tab use krta to lock string

# %%
df.iloc[3]

# %% [markdown]
# * These Above process is also called Data Slicing
# * Bara dataset ma sa kuxh chezon ko nikal lena
# * slicing ko use krna ka liya we use iloc, loc, index

# %%
import seaborn as sns

# %%
kashti = sns.load_dataset("titanic")

# %%
kashti.sample(100)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 648         0       3    male   NaN      0      0   7.5500        S  Third
# 770         0       3    male  24.0      0      0   9.5000        S  Third
# 204         1       3    male  18.0      0      0   8.0500        S  Third
# 267         1       3    male  25.0      1      0   7.7750        S  Third
# 365         0       3    male  30.0      0      0   7.2500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 25          1       3  female  38.0      1      5  31.3875        S  Third
# 647         1       1    male  56.0      0      0  35.5000        C  First
# 391         1       3    male  21.0      0      0   7.7958        S  Third
# 691         1       3  female   4.0      0      1  13.4167        C  Third
# 363         0       3    male  35.0      0      0   7.0500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti[kashti["age"] < 5]
# kashti ka ander kashti ka dataset ma sa age ma un logon ka dataset dekhow jo 5 saal sa kam umer ka hon
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 7           0       3    male  2.00      3      1   21.0750        S   Third
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 16          0       3    male  2.00      4      1   29.1250        Q   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 63          0       3    male  4.00      3      2   27.9000        S   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 119         0       3  female  2.00      4      2   31.2750        S   Third
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 171         0       3    male  4.00      4      1   29.1250        Q   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# ...

# %%
kashti[kashti["fare"] < 5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# ...
