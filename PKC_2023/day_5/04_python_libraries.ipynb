# %% [markdown]
# ### What is the full form if pandas, numpy, matplotlib, Seaborn, plotly, scipy ?
# #### Important Libraries for Data Scientist?
#
# 1. pandas = Kisi bi tareeka ka Dataframes ko handle krna ka liya use hoti ha. like excel ka backend ma pandas hi use ho ra hota ha. Jesa excel ma functioning krta ha same usi tra is ma bi functioning kre ga..
# Question: Check the difference between pandas and excel?
#
# 2. numpy = Data type ko samjahana ka liya use hoti jesa ka check krna data ki dimensions etc like 1d 2d 3d
#
# 3. matplotlib = Use for ploting jitna kism ka bi plot banana hain wo is ki madad sa banain ga.. like lineplot etc
#
# 4. seaborn = Ye Matplotlib ki base pr baney ha lakin is ka extra function bi ha but it is a seperate library
#
# 5. plotly = High intellected plots hain is ma. Ye interactive graph banana ka liya animattion plots banana ka liya. Ye next level advance chez ha plots ki domain ma
#
# 6. Scipy.stats or Scipy =  Ye statistics analysis ko use krna ka liyaa
#
# 7. Scikit-learn means science kit learn = It is used for ML. Pichla data ko use kr ka future predict krna
#
# 8. Keras
# 9.  Streamlit = It is used for dashboards next level. Ap apna thesis is pr deploy kr sakta hai is ma hum apps bi bana sakta hain like youtube ki video download krna wali app
# 10. Check their function and in ko kis tra use krna hota ha

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import plotly as px
# Har notebook banata waqt ap na sepetately import krna ha.
#

# %%
# Plots kesa banana hain 
import seaborn as sns 

diamonds= sns.load_dataset("diamonds")

sns.set_theme(style="whitegrid")


clarity_ranking = ['I1',"SI2","SI1","VS2","VS1","VVS2","VVS1","IF"]

sns.boxenplot(x="clarity", y="carat", 
            color="b", order=clarity_ranking,
            scale="linear", data=diamonds)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.value_counts()
# Out:
# carat  cut        color  clarity  depth  table  price  x      y      z
# 0.79   Ideal      G      SI1      62.3   57.0   2898   5.90   5.85   3.66    5
# 0.31   Very Good  D      SI1      63.5   56.0   732    4.31   4.29   2.73    2
# 0.32   Ideal      H      VVS2     61.8   55.0   645    4.38   4.42   2.72    2
# 0.31   Good       D      SI1      63.5   56.0   571    4.29   4.31   2.73    2
# 0.30   Very Good  J      VS1      63.4   57.0   506    4.26   4.23   2.69    2
#                                                                             ..
# 0.50   Ideal      I      VS1      62.2   55.0   1282   5.07   5.11   3.16    1
#                          VS2      61.6   54.0   1220   5.11   5.14   3.16    1
#                                   61.9   56.0   1410   5.08   5.13   3.16    1
#                                   62.0   55.0   1110   5.10   5.12   3.17    1
# 5.01   Fair       J      I1       65.5   59.0   18018  10.74  10.54  6.98    1
# Length: 53794, dtype: int64

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")

# Load the example dataset of brain network correlations
df = sns.load_dataset("brain_networks", header=[0, 1, 2], index_col=0)

# Pull out a specific subset of networks
used_networks = [1, 3, 4, 5, 6, 7, 8, 11, 12, 13, 16, 17]
used_columns = (df.columns.get_level_values("network")
                          .astype(int)
                          .isin(used_networks))
df = df.loc[:, used_columns]

# Compute the correlation matrix and average over networks
corr_df = df.corr().groupby(level="network").mean()
corr_df.index = corr_df.index.astype(int)
corr_df = corr_df.sort_index().T

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 6))

# Draw a violinplot with a narrower bandwidth than the default
sns.violinplot(data=corr_df, palette="Set3", bw=.2, cut=1, linewidth=1)

# Finalize the figure
ax.set(ylim=(-.7, 1.05))
sns.despine(left=True, bottom=True)

# %%
brain_networks.head()
