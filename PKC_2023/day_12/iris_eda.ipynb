# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the data
phool = sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
phool.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
phool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
phool.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
phool1 = phool

# %%
phool1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
phool1.isnull().sum() * 100/len(phool1)
# Out:
# sepal_length    0.0
# sepal_width     0.0
# petal_length    0.0
# petal_width     0.0
# species         0.0
# dtype: float64

# %%
phool1.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
phool1['petal_length'].unique()
# Out:
# array([1.4, 1.3, 1.5, 1.7, 1.6, 1.1, 1.2, 1. , 1.9, 4.7, 4.5, 4.9, 4. ,
#        4.6, 3.3, 3.9, 3.5, 4.2, 3.6, 4.4, 4.1, 4.8, 4.3, 5. , 3.8, 3.7,
#        5.1, 3. , 6. , 5.9, 5.6, 5.8, 6.6, 6.3, 6.1, 5.3, 5.5, 6.7, 6.9,
#        5.7, 6.4, 5.4, 5.2])

# %%
phool1['petal_length'].nunique()
# Out:
# 43

# %%
phool1['petal_width'].unique()
# Out:
# array([0.2, 0.4, 0.3, 0.1, 0.5, 0.6, 1.4, 1.5, 1.3, 1.6, 1. , 1.1, 1.8,
#        1.2, 1.7, 2.5, 1.9, 2.1, 2.2, 2. , 2.4, 2.3])

# %%
phool1['petal_width'].nunique()
# Out:
# 22

# %%
phool1['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
phool1['petal_length'].max()
# Out:
# 6.9

# %%
phool1['petal_width'].mean()
# Out:
# 1.1993333333333336

# %%
phool1.species.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.boxenplot(x="species", y='sepal_length', data=phool1)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.scatterplot(x="petal_length", y='sepal_width', data=phool1, hue='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_width'>

# %%
sns.pairplot(phool1)

# %%
phool1.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
phool1.boxplot()
# Out:
# <Axes: >

# %%
sns.stripplot(data=phool1 , x="species" , y="sepal_length" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sns.stripplot(data=phool1 , x="species" , y="sepal_length" )
#
# File c:\Users\Windows 10\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2503, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, native_scale, formatter, legend, ax, **kwargs)
#    2495 def stripplot(
#    2496     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    2497     jitter=True, dodge=False, orient=None, color=None, palette=None,
#    (...)
#    2500     ax=None, **kwargs
#    2501 ):
# -> 2503     p = _CategoricalPlotterNew(
#    2504         data=data,
#    2505         variables=_CategoricalPlotterNew.get_semantics(locals()),
#    2506         order=order,
#    2507         orient=orient,
# ...

# %%
# HEat Map
corr = phool.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr)
plt.title("HEat map ka plot")
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_9308\1521034774.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = phool.corr()
# Text(0.5, 1.0, 'HEat map ka plot')
